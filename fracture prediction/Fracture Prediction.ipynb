# %% [markdown]
# # 設定

# %%
#Library Setting
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from warnings import simplefilter
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import RFECV
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import make_scorer, f1_score
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from matplotlib.ticker import MaxNLocator
from scipy.stats import skew, kurtosis
from tqdm import tqdm
import scipy.stats as stats
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import confusion_matrix,classification_report

# Set font properties so that traditional Chinese could be shown on the graphs
font = {'family': 'Microsoft JhengHei', 'weight': 'normal', 'size': 12}
# Set font properties for all plots
plt.rc('font', **font)

# Turn off warnings
simplefilter("ignore")

# %% [markdown]
# # Part 1 : 載入資料

# %%
'''
from google.colab import drive
drive.mount('/content/drive')
# 請輸入放excel的路徑
import os
os.chdir('/content/drive/MyDrive/traffic processing time') # 更改路徑
'''
# Out:
# "\nfrom google.colab import drive\ndrive.mount('/content/drive')\n# 請輸入放excel的路徑\nimport os\nos.chdir('/content/drive/MyDrive/traffic processing time') # 更改路徑\n"

# %% [markdown]
# 資料說明:
#
# 1.「age」「height」「weight_data」為連續變數，其他為類別變數
#
# 2.For 類別變數: Default: 0=否,1=是
#
# *「education (x)」: 1=不識字,2=國小,3=國中,4=高中,5=大學,6=研究所,7=其他
#
# *「gender」: 0=女,1=男

# %%
# Data Part
df = pd.read_excel('最終數據.xlsx')

# Set 'record_id' as index
if df.index.name != 'record_id':
    df.set_index('record_id', inplace=True)

# Set NaN value to 0
df = df.fillna(0)

# Set Column 'baseline_monthly 每個月收入多少' to 1 or 0
df.loc[df['baseline_monthly 每個月收入多少'] != 2, 'baseline_monthly 每個月收入多少'] = 0 
df.loc[df['baseline_monthly 每個月收入多少'] == 2, 'baseline_monthly 每個月收入多少'] = 1

# filtered out those rows with column 'enroll' or 'follow1(是否活著)' as 0
df = df[~((df['enroll'] == 0) | (df['follow1(是否活著)']==0))]

# drop two columns that aren't relevant to 
df.drop(['enroll', 'follow1(是否活著)'], axis=1, inplace=True)

# %% [markdown]
# # Part 2 : 資料預覽

# %%
# Show a few rows
display(df.head())
# Out:
#            gender (x)  age (x)  height (x)  weight_data (x)  education (x)  \
# record_id
# 1                 1.0     69.0       165.0             65.4            5.0
# 2                 1.0     82.4       164.0             67.2            1.0
# 4                 0.0     69.6       155.0             60.7            1.0
# 5                 0.0     64.1       152.0             62.1            4.0
# 6                 0.0     81.5       141.0             51.0            1.0
#
#            living___1 (x)  osteoporosis_judge_o 是否骨質疏鬆  \
# record_id
# 1                     0.0                          0.0
# 2                     0.0                          1.0
# 4                     0.0                          0.0
# 5                     1.0                          0.0
# 6                     0.0                          1.0
#
#            vivifrail_judge3 (x) SPPB分數是否大於9分  mna_score (x)  \
# record_id
# 1                                        1.0            0.0
# 2                                        1.0            1.0
# 4                                        1.0            1.0
# 5                                        0.0            0.0
# 6                                        1.0            0.0
#
#            menopause 早發性停經< 45歲 (x)  ...  sarcopenia_diagnosis 是否確診肌少症(X)  \
# record_id                            ...
# 1                               0.0  ...                                0
# 2                               0.0  ...                                0
# 4                               1.0  ...                                0
# 5                               0.0  ...                                0
# 6                               0.0  ...                                0
#
#            calf_judge 小腿圍是否不足(X)  hand_strength_judge 手握力是否不足(X)  \
# record_id
# 1                              1                               0
# 2                              1                               0
# 4                              1                               0
# 5                              0                               0
# 6                              1                               0
#
#            sit_and_stand_up_judge 起立坐下  sixm_sec_judge 6公尺步行速度太慢 (超過6秒)  \
# record_id
# 1                                  0.0                                0
# 2                                  0.0                                0
# 4                                  1.0                                0
# 5                                  1.0                                0
# 6                                  0.0                                0
#
#            sarcopenia_judge 是否有肌肉質量不足(x)  兩者髖關節是否不正常合(X)  兩者骨頸是否不正常(X)  \
# record_id
# 1                                      0               0             0
# 2                                      0               0             0
# 4                                      0               0             0
# 5                                      0               0             0
# 6                                      0               0             0
#
#            dxa_spinet_n 腰椎T值是否不正常  (每年更新)fx 骨折
# record_id
# 1                             0.0          0.0
# 2                             0.0          0.0
# 4                             1.0          0.0
# 5                             0.0          0.0
# 6                             0.0          0.0
#
# [5 rows x 30 columns]

# %%
# Preview data
def DataPreview(df):
    print("**DataFrame Information:**")
    df.info()
    print("\n**Missing Values:**")
    print(df.isna().sum())
    print("\n**Duplicated Rows:**")
    print(df.duplicated().sum())
    print()

# %%
DataPreview(df)
# Out:
# **DataFrame Information:**
# <class 'pandas.core.frame.DataFrame'>
# Index: 469 entries, 1 to 634
# Data columns (total 30 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender (x)                         469 non-null    float64
#  1   age (x)                            469 non-null    float64
#  2   height (x)                         469 non-null    float64
#  3   weight_data (x)                    469 non-null    float64
#  4   education (x)                      469 non-null    float64
#  5   living___1 (x)                     469 non-null    float64
#  6   osteoporosis_judge_o 是否骨質疏鬆        469 non-null    float64
#  7   vivifrail_judge3 (x) SPPB分數是否大於9分  469 non-null    float64
#  8   mna_score (x)                      469 non-null    float64
#  9   menopause 早發性停經< 45歲 (x)           469 non-null    float64
#  10  baseline_monthly 每個月收入多少           469 non-null    float64
#  11  frax_5(骨折史)                        469 non-null    float64
#  12  frax_7(目前吸菸)                       469 non-null    float64
#  13  frax_11 是否過度飲酒                     469 non-null    float64
#  14  frax_6 父母骨折史                       469 non-null    float64
#  15  frax_10 次發性骨鬆                      469 non-null    float64
#  16  frax_9 類風溼性關節炎                     469 non-null    float64
#  17  dm 是否有糖尿病                          469 non-null    float64
#  18  exercise                           469 non-null    float64
#  19  (每年更新)follow_2 是否有跌倒               469 non-null    float64
#  20  sarcopenia_diagnosis 是否確診肌少症(X)    469 non-null    int64
#  21  calf_judge 小腿圍是否不足(X)              469 non-null    int64
#  22  hand_strength_judge 手握力是否不足(X)     469 non-null    int64
#  23  sit_and_stand_up_judge 起立坐下        469 non-null    float64
#  24  sixm_sec_judge 6公尺步行速度太慢 (超過6秒)    469 non-null    int64
#  25  sarcopenia_judge 是否有肌肉質量不足(x)      469 non-null    int64
#  26  兩者髖關節是否不正常合(X)                     469 non-null    int64
#  27  兩者骨頸是否不正常(X)                       469 non-null    int64
#  28  dxa_spinet_n 腰椎T值是否不正常             469 non-null    float64
#  29  (每年更新)fx 骨折                        469 non-null    float64
# dtypes: float64(23), int64(7)
# memory usage: 113.6 KB
#
# **Missing Values:**
# gender (x)                           0
# age (x)                              0
# height (x)                           0
# weight_data (x)                      0
# education (x)                        0
# living___1 (x)                       0
# osteoporosis_judge_o 是否骨質疏鬆          0
# vivifrail_judge3 (x) SPPB分數是否大於9分    0
# mna_score (x)                        0
# menopause 早發性停經< 45歲 (x)             0
# baseline_monthly 每個月收入多少             0
# frax_5(骨折史)                          0
# frax_7(目前吸菸)                         0
# frax_11 是否過度飲酒                       0
# frax_6 父母骨折史                         0
# frax_10 次發性骨鬆                        0
# frax_9 類風溼性關節炎                       0
# dm 是否有糖尿病                            0
# exercise                             0
# (每年更新)follow_2 是否有跌倒                 0
# sarcopenia_diagnosis 是否確診肌少症(X)      0
# calf_judge 小腿圍是否不足(X)                0
# hand_strength_judge 手握力是否不足(X)       0
# sit_and_stand_up_judge 起立坐下          0
# sixm_sec_judge 6公尺步行速度太慢 (超過6秒)      0
# sarcopenia_judge 是否有肌肉質量不足(x)        0
# 兩者髖關節是否不正常合(X)                       0
# 兩者骨頸是否不正常(X)                         0
# dxa_spinet_n 腰椎T值是否不正常               0
# (每年更新)fx 骨折                          0
# dtype: int64
#
# **Duplicated Rows:**
# 0

# %% [markdown]
# 根據資料規則的理解，總共有 469 個樣本。我們也為每一欄設定正確的資料類型（我們不將某些特徵指定為分類變量，因為之後還是得進行轉換。）且確定沒有缺失值和樣本重複的狀況。接著我們可以繼續預處理這些樣本。

# %% [markdown]
# # Part 3 : 資料預處理

# %%
# Write a class for feature selection
class DataPreProcess:
    def __init__(self): # Define some common attributes in the class
        pass

# %%
# X is a df that contains multiple features
def FeatureProcessing(self, X , review = None):
    # Set the display option to show all columns (In case there are columns being truncated when there are lots of columns)
    pd.options.display.max_columns = None
    
    # Print the number of unique value of each column
    df_unique_value = pd.DataFrame(index = ['Num_unique_vals',] , columns = X.columns)
    for column in X.columns:
        df_unique_value.at['Num_unique_vals',column] = X[column].nunique()
    print('\033[1mHere is the number of unique values of each columns :\033[0m')
    display(df_unique_value)

    # Print all the column names of categorical data that need transformation.
    categorical_colnames = X.select_dtypes(include=['object','category']).columns.values
    print(f'\n\033[1mThe columns of categorical data are :\033[0m \n {categorical_colnames}')

    # Check if all variables aren't either categorical or object, if yes then label encode those variables.
    for colname in X.select_dtypes(include=['object','category']):
        X[colname], _ = X[colname].factorize()

    # (optional) review after factorization if designated
    if review == True:
        print("\n\033[1mHere is the transformed dataframe :\033[0m")
        display(X.head())
        # Print all the column names of categorical data that need transformation.
        categorical_colnames = X.select_dtypes(include=['object','category']).columns.values
        print(f'\n\033[1mAfter transformation, the columns of categorical data are :\033[0m \n {categorical_colnames}')
        
    # Reset the display option to default
    pd.reset_option('display.max_columns')

# Add the method to the class FeatureSelector
DataPreProcess.FeatureProcessing = FeatureProcessing

# %%
DPP = DataPreProcess()
DPP.FeatureProcessing(df,review = True)
# Out:
# Here is the number of unique values of each columns :
#                 gender (x) age (x) height (x) weight_data (x) education (x)  \
# Num_unique_vals          2     252         48             257             7
#
#                 living___1 (x) osteoporosis_judge_o 是否骨質疏鬆  \
# Num_unique_vals              2                           2
#
#                 vivifrail_judge3 (x) SPPB分數是否大於9分 mna_score (x)  \
# Num_unique_vals                                 2             2
#
#                 menopause 早發性停經< 45歲 (x) baseline_monthly 每個月收入多少 frax_5(骨折史)  \
# Num_unique_vals                        2                        2           2
#
#                 frax_7(目前吸菸) frax_11 是否過度飲酒 frax_6 父母骨折史 frax_10 次發性骨鬆  \
# Num_unique_vals            2              2            2             2
#
#                 frax_9 類風溼性關節炎 dm 是否有糖尿病 exercise (每年更新)follow_2 是否有跌倒  \
# Num_unique_vals              2         2        2                    2
#
#                 sarcopenia_diagnosis 是否確診肌少症(X) calf_judge 小腿圍是否不足(X)  \
# Num_unique_vals                               2                     2
#
#                 hand_strength_judge 手握力是否不足(X) sit_and_stand_up_judge 起立坐下  \
# Num_unique_vals                              2                           2
#
#                 sixm_sec_judge 6公尺步行速度太慢 (超過6秒) sarcopenia_judge 是否有肌肉質量不足(x)  \
# Num_unique_vals                               2                             2
#
#                 兩者髖關節是否不正常合(X) 兩者骨頸是否不正常(X) dxa_spinet_n 腰椎T值是否不正常 (每年更新)fx 骨折
# Num_unique_vals              2            2                      2           2
# The columns of categorical data are :
#  []
#
# Here is the transformed dataframe :
#            gender (x)  age (x)  height (x)  weight_data (x)  education (x)  \
# record_id
# 1                 1.0     69.0       165.0             65.4            5.0
# 2                 1.0     82.4       164.0             67.2            1.0
# 4                 0.0     69.6       155.0             60.7            1.0
# 5                 0.0     64.1       152.0             62.1            4.0
# 6                 0.0     81.5       141.0             51.0            1.0
#
#            living___1 (x)  osteoporosis_judge_o 是否骨質疏鬆  \
# record_id
# 1                     0.0                          0.0
# 2                     0.0                          1.0
# 4                     0.0                          0.0
# 5                     1.0                          0.0
# 6                     0.0                          1.0
#
#            vivifrail_judge3 (x) SPPB分數是否大於9分  mna_score (x)  \
# record_id
# 1                                        1.0            0.0
# 2                                        1.0            1.0
# 4                                        1.0            1.0
# 5                                        0.0            0.0
# 6                                        1.0            0.0
#
#            menopause 早發性停經< 45歲 (x)  baseline_monthly 每個月收入多少  frax_5(骨折史)  \
# record_id
# 1                               0.0                       0.0          0.0
# 2                               0.0                       1.0          0.0
# 4                               1.0                       0.0          0.0
# 5                               0.0                       0.0          0.0
# 6                               0.0                       1.0          0.0
#
#            frax_7(目前吸菸)  frax_11 是否過度飲酒  frax_6 父母骨折史  frax_10 次發性骨鬆  \
# record_id
# 1                   0.0             0.0           0.0            0.0
# 2                   0.0             0.0           0.0            0.0
# 4                   0.0             0.0           0.0            1.0
# 5                   0.0             0.0           0.0            0.0
# 6                   0.0             0.0           0.0            0.0
#
#            frax_9 類風溼性關節炎  dm 是否有糖尿病  exercise  (每年更新)follow_2 是否有跌倒  \
# record_id
# 1                     0.0        0.0       1.0                   0.0
# 2                     0.0        1.0       1.0                   1.0
# 4                     0.0        0.0       1.0                   0.0
# 5                     0.0        1.0       1.0                   0.0
# 6                     0.0        1.0       1.0                   1.0
#
#            sarcopenia_diagnosis 是否確診肌少症(X)  calf_judge 小腿圍是否不足(X)  \
# record_id
# 1                                        0                      1
# 2                                        0                      1
# 4                                        0                      1
# 5                                        0                      0
# 6                                        0                      1
#
#            hand_strength_judge 手握力是否不足(X)  sit_and_stand_up_judge 起立坐下  \
# record_id
# 1                                       0                          0.0
# 2                                       0                          0.0
# 4                                       0                          1.0
# 5                                       0                          1.0
# 6                                       0                          0.0
#
#            sixm_sec_judge 6公尺步行速度太慢 (超過6秒)  sarcopenia_judge 是否有肌肉質量不足(x)  \
# record_id
# 1                                        0                              0
# 2                                        0                              0
# 4                                        0                              0
# 5                                        0                              0
# 6                                        0                              0
#
#            兩者髖關節是否不正常合(X)  兩者骨頸是否不正常(X)  dxa_spinet_n 腰椎T值是否不正常  (每年更新)fx 骨折
# record_id
# 1                       0             0                     0.0          0.0
# 2                       0             0                     0.0          0.0
# 4                       0             0                     1.0          0.0
# 5                       0             0                     0.0          0.0
# 6                       0             0                     0.0          0.0
# After transformation, the columns of categorical data are :
#  []

# %% [markdown]
# 到目前為止，我們已妥善處理每個儲存格。我們也確認了欄位應包含的值。
# 我們可以觀察到除了'age (x)','height (x)','weight_data (x)'外，其餘都是分類特徵。又在分類特徵中，'education (x)'具有7個可能值，須注意該欄位是名義數據而不是序數數據。

# %% [markdown]
# # Part 4 : 探索性分析

# %%
# Set the columns as features or target
X = df.copy()
y = X.pop('(每年更新)fx 骨折')

# %%
# Write a class for feature selection
class ExploratoryAnalysis:
    def __init__(self): # Define some common attributes in the class
        pass

# %%
def DataInfo(self, df):
    # Set the display option to show all columns (In case there are columns being truncated when there are lots of columns)
    pd.options.display.max_columns = None

    # Calculate skewness, kurtosis, and coefficient of variation
    skew_val, kurt_val, cof_var = skew(df) ,kurtosis(df), df.std()/df.mean()

    # Create a df for skewness, kurtosis, and coefficient of variation
    df_stats = pd.DataFrame({'skewness': skew_val, 'kurtosis': kurt_val,'coefficient of variation': cof_var}).transpose()

    # Add df_stats to df.describe()
    description = pd.concat([df.describe(),df_stats],axis = 0)

    # Display the df
    print('\033[1mHere is the descriptive statistics each columns :\033[0m')
    display(description)
    
    # Reset the display option to default
    pd.reset_option('display.max_columns')
    
# Add the method to the class ExploratoryAnalysis
ExploratoryAnalysis.DataInfo = DataInfo

# %%
def TargetDist(self, y, Dtype = "Numerical"): # assume y is a series
    if Dtype == "Numerical":
        # Plotting
        fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
        
        #Turn y into DataFrame for easier operation
        df = pd.DataFrame(y)
        
        # Violin plot (Show the boxplot and the distribution)
        sns.violinplot(data=df.reset_index(drop=True),ax=axes[0,0])
        axes[0,0].set_title(f'Violin Plot')
        
        # Boxplot (Zoom in the boxplot within the violin plot and visualize the the number of outliers)
        sns.boxplot(y=y,ax=axes[0,1], showfliers=True)
        axes[0,1].set_title('Box Plot with outlier')
        axes[0,1].set_ylabel('')
        axes[0,1].set_xlabel(f'{y.name}')
        
        # Distribution plot (Visualize how tilted the distribution is)
        axes[1,0].plot(range(1,len(y)+1), y.sort_values(ascending = True))
        axes[1,0].set_title(f'Line Plot of {y.name} (ascending)')
        
        #QQ-Plot (Visualize the distribution against normal distribution)
        stats.probplot(y, dist="norm", plot=axes[1,1])
        axes[1,1].set_title(f'QQ Plot of {y.name} against normal distribution')
        axes[1,1].set_xlabel('Theoretical Quantiles')
        axes[1,1].set_ylabel('Sample Quantiles')
        
        # Show the plot
        print(f'\033[1mHere is the distribution plot of {y.name} :\033[0m')
        # Adjust layout
        plt.tight_layout()
        plt.show()
        
    if Dtype == "Categorical":
        # Plotting
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 6))
        
        # Bar plot
        unique_values, value_counts = np.unique(y, return_counts=True)
        bars = axes[0].bar(unique_values, value_counts, color='skyblue')
        axes[0].set_xlabel('Value')
        axes[0].set_xticks(unique_values)
        axes[0].set_ylabel('Frequency')
        # Add labels on top of bars by calculating the position of each bar
        for bar, count in zip(bars, value_counts):
            axes[0].text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(count),ha='center', va='bottom')
        axes[0].set_title(f'Bar chart of {y.name}')
        
        # Pie Plot
        percentage_counts = value_counts / value_counts.sum()
        axes[1].pie(percentage_counts, labels=unique_values, autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue', 'lightgreen', 'lightsalmon'], startangle=90)
        axes[1].set_title(f'Pie chart of {y.name}')
        axes[1].legend(loc='lower right')
        axes[1].axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle

        # Show the plot
        print(f'\033[1mHere is the distribution plot of {y.name} :\033[0m\n')
        # Adjust layout
        plt.tight_layout()
        plt.show()
        
# Add the method to the class ExploratoryAnalysis
ExploratoryAnalysis.TargetDist = TargetDist

# %%
EA = ExploratoryAnalysis()
EA.DataInfo(df)
# Out:
# Here is the descriptive statistics each columns :
#                           gender (x)     age (x)  height (x)  weight_data (x)  \
# count                     469.000000  469.000000  469.000000       469.000000
# mean                        0.191898   74.279744  154.809168        59.260128
# std                         0.394214    8.619105    7.728523        10.284097
# min                         0.000000   51.400000  135.000000        30.300000
# 25%                         0.000000   68.800000  150.000000        52.500000
# 50%                         0.000000   74.300000  154.000000        58.800000
# 75%                         0.000000   80.200000  160.000000        65.100000
# max                         1.000000   96.100000  179.000000        96.200000
# skewness                    1.564793   -0.193152    0.303306         0.458143
# kurtosis                    0.448578   -0.350857   -0.121635         0.667016
# coefficient of variation    2.054290    0.116036    0.049923         0.173542
#
#                           education (x)  living___1 (x)  \
# count                        469.000000      469.000000
# mean                           2.852878        0.208955
# std                            1.739958        0.406996
# min                            1.000000        0.000000
# 25%                            1.000000        0.000000
# 50%                            2.000000        0.000000
# 75%                            4.000000        0.000000
# max                            8.000000        1.000000
# skewness                       0.628532        1.431735
# kurtosis                      -0.946485        0.049865
# coefficient of variation       0.609896        1.947769
#
#                           osteoporosis_judge_o 是否骨質疏鬆  \
# count                                      469.000000
# mean                                         0.605544
# std                                          0.489255
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          1.000000
# 75%                                          1.000000
# max                                          1.000000
# skewness                                    -0.431907
# kurtosis                                    -1.813456
# coefficient of variation                     0.807961
#
#                           vivifrail_judge3 (x) SPPB分數是否大於9分  mna_score (x)  \
# count                                            469.000000     469.000000
# mean                                               0.767591       0.102345
# std                                                0.422820       0.303426
# min                                                0.000000       0.000000
# 25%                                                1.000000       0.000000
# 50%                                                1.000000       0.000000
# 75%                                                1.000000       0.000000
# max                                                1.000000       1.000000
# skewness                                          -1.267095       2.623899
# kurtosis                                          -0.394470       4.884848
# coefficient of variation                           0.550840       2.964722
#
#                           menopause 早發性停經< 45歲 (x)  baseline_monthly 每個月收入多少  \
# count                                   469.000000                469.000000
# mean                                      0.100213                  0.522388
# std                                       0.300605                  0.500032
# min                                       0.000000                  0.000000
# 25%                                       0.000000                  0.000000
# 50%                                       0.000000                  1.000000
# 75%                                       0.000000                  1.000000
# max                                       1.000000                  1.000000
# skewness                                  2.662724                 -0.089642
# kurtosis                                  5.090098                 -1.991964
# coefficient of variation                  2.999651                  0.957204
#
#                           frax_5(骨折史)  frax_7(目前吸菸)  frax_11 是否過度飲酒  \
# count                      469.000000    469.000000      469.000000
# mean                         0.149254      0.023454        0.014925
# std                          0.356719      0.151502        0.121384
# min                          0.000000      0.000000        0.000000
# 25%                          0.000000      0.000000        0.000000
# 50%                          0.000000      0.000000        0.000000
# 75%                          0.000000      0.000000        0.000000
# max                          1.000000      1.000000        1.000000
# skewness                     1.968613      6.297649        8.000947
# kurtosis                     1.875439     37.660381       62.015152
# coefficient of variation     2.390017      6.459515        8.132713
#
#                           frax_6 父母骨折史  frax_10 次發性骨鬆  frax_9 類風溼性關節炎  \
# count                       469.000000     469.000000      469.000000
# mean                          0.049041       0.159915        0.017058
# std                           0.216183       0.366918        0.129624
# min                           0.000000       0.000000        0.000000
# 25%                           0.000000       0.000000        0.000000
# 50%                           0.000000       0.000000        0.000000
# 75%                           0.000000       0.000000        0.000000
# max                           1.000000       1.000000        1.000000
# skewness                      4.176467       1.855718        7.459380
# kurtosis                     15.442874       1.443689       53.642354
# coefficient of variation      4.408258       2.294463        7.599219
#
#                            dm 是否有糖尿病    exercise  (每年更新)follow_2 是否有跌倒  \
# count                     469.000000  469.000000            469.000000
# mean                        0.238806    0.837953              0.296375
# std                         0.426809    0.368887              0.457146
# min                         0.000000    0.000000              0.000000
# 25%                         0.000000    1.000000              0.000000
# 50%                         0.000000    1.000000              0.000000
# 75%                         0.000000    1.000000              1.000000
# max                         1.000000    1.000000              1.000000
# skewness                    1.225245   -1.834240              0.891803
# kurtosis                   -0.498775    1.364437             -1.204687
# coefficient of variation    1.787264    0.440224              1.542457
#
#                           sarcopenia_diagnosis 是否確診肌少症(X)  \
# count                                          469.000000
# mean                                             0.196162
# std                                              0.397517
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                              1.000000
# skewness                                         1.530313
# kurtosis                                         0.341858
# coefficient of variation                         2.026470
#
#                           calf_judge 小腿圍是否不足(X)  \
# count                                469.000000
# mean                                   0.484009
# std                                    0.500278
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    1.000000
# max                                    1.000000
# skewness                               0.063999
# kurtosis                              -1.995904
# coefficient of variation               1.033614
#
#                           hand_strength_judge 手握力是否不足(X)  \
# count                                         469.000000
# mean                                            0.375267
# std                                             0.484709
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
# skewness                                        0.515224
# kurtosis                                       -1.734545
# coefficient of variation                        1.291638
#
#                           sit_and_stand_up_judge 起立坐下  \
# count                                      469.000000
# mean                                         0.452026
# std                                          0.498225
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          1.000000
# max                                          1.000000
# skewness                                     0.192787
# kurtosis                                    -1.962833
# coefficient of variation                     1.102204
#
#                           sixm_sec_judge 6公尺步行速度太慢 (超過6秒)  \
# count                                          469.000000
# mean                                             0.394456
# std                                              0.489255
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              1.000000
# max                                              1.000000
# skewness                                         0.431907
# kurtosis                                        -1.813456
# coefficient of variation                         1.240329
#
#                           sarcopenia_judge 是否有肌肉質量不足(x)  兩者髖關節是否不正常合(X)  \
# count                                        469.000000      469.000000
# mean                                           0.447761        0.023454
# std                                            0.497795        0.151502
# min                                            0.000000        0.000000
# 25%                                            0.000000        0.000000
# 50%                                            0.000000        0.000000
# 75%                                            1.000000        0.000000
# max                                            1.000000        1.000000
# skewness                                       0.210105        6.297649
# kurtosis                                      -1.955856       37.660381
# coefficient of variation                       1.111741        6.459515
#
#                           兩者骨頸是否不正常(X)  dxa_spinet_n 腰椎T值是否不正常  (每年更新)fx 骨折
# count                       469.000000              469.000000   469.000000
# mean                          0.006397                0.110874     0.042644
# std                           0.079808                0.314312     0.202269
# min                           0.000000                0.000000     0.000000
# 25%                           0.000000                0.000000     0.000000
# 50%                           0.000000                0.000000     0.000000
# 75%                           0.000000                0.000000     0.000000
# max                           1.000000                1.000000     1.000000
# skewness                     12.383044                2.478695     4.527090
# kurtosis                    151.339771                4.143931    18.494543
# coefficient of variation     12.476588                2.834848     4.743203

# %%
EA.TargetDist(df['(每年更新)fx 骨折'],"Categorical")
# Out:
# Here is the distribution plot of (每年更新)fx 骨折 :

# %% [markdown]
# 我們可以發現，我們的目標變數有樣本不均衡的問題(0的有96%，而1的只有4%)，這對於某些模型來說，會影響到預測為1的準確度，因此訓練前必須重新抽選樣本。

# %% [markdown]
# # Part 5 : 模型訓練

# %% [markdown]
# # Part 5-1 : 重新抽選樣本

# %% [markdown]
# 考慮到樣本量及樣本不均的問題，這邊假設0的樣本數不做變動的情況下，採用SMOTE做over-sampling，以補足1的樣本量不足的問題，這邊先將比例補成90%的0及10%的1

# %%
# Calculate the number of samples that are not equal to 1 
NumberOfNon1 = sum(y!=1)
RatioOf1 = 0.1

# Calculate the number of 1 samples needed
NumberOf1 = RatioOf1* NumberOfNon1 / (1-RatioOf1)

# %%
# Define the desired sampling strategy
sampling_strategy = {1: int(NumberOf1)}

# Instantiate SMOTE
smote = SMOTE(sampling_strategy=sampling_strategy, random_state=42)

# Fit and transform the data using SMOTE
X_resampled, y_resampled = smote.fit_resample(X, y)

# Print total number of sample and total number of samples with target value as 1
print(f'There are total of {len(X_resampled)} samples after resampling, with {int(NumberOf1)} samples with target value as 1')
# Out:
# There are total of 498 samples after resampling, with 49 samples with target value as 1
#   File "C:\Users\misto\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")

# %%
EA.TargetDist(y_resampled,"Categorical")
# Out:
# Here is the distribution plot of (每年更新)fx 骨折 :

# %% [markdown]
# 我們可以看到over-sampling後，樣本數共有598個，而target為1的樣本數來到149個，使得target的分布也分別來到0:75%,1:25%

# %% [markdown]
# # Part 5-2 : 特徵篩選

# %%
# Split the resampled data into train and test sets with stratification sampling
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, stratify=y_resampled, random_state=30)

# %%
# Standardize the features (mean=0 and variance=1)
Columns = ['age (x)','height (x)','weight_data (x)']
scaler = StandardScaler()

# Get a copy of X_train and X_test
X_train_Standardized = X_train.copy() 
X_test_Standardized = X_test.copy()

# Fit and transform X_train and transform X_test based on the fit from X_train to prevent data leakage
X_train_Standardized[Columns] = scaler.fit_transform(X_train_Standardized[Columns])
X_test_Standardized[Columns] = scaler.transform(X_test_Standardized[Columns])

# %%
# Fit logistic regression model using statsmodels
logit_model = sm.Logit(y_train, X_train_Standardized)
logit_result = logit_model.fit()

# Print summary of the logistic regression model
print(logit_result.summary())

# Access p-values and odds ratios from the results
p_values = logit_result.pvalues
odds_ratios = np.exp(logit_result.params)

# Print p-values and odds ratios
print(f"\nP-values of {type(logit_model).__name__} model:")
print(p_values)
print(f"\nOdds Ratios {type(logit_model).__name__} model:")
print(odds_ratios)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.164058
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            (每年更新)fx 骨折   No. Observations:                  348
# Model:                          Logit   Df Residuals:                      319
# Method:                           MLE   Df Model:                           28
# Date:                Sun, 12 May 2024   Pseudo R-squ.:                  0.4873
# Time:                        04:20:00   Log-Likelihood:                -57.092
# converged:                      False   LL-Null:                       -111.36
# Covariance Type:            nonrobust   LLR p-value:                 2.005e-11
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# gender (x)                            0.8152      1.141      0.715      0.475      -1.420       3.051
# age (x)                               0.3847      0.366      1.052      0.293      -0.332       1.102
# height (x)                            0.3387      0.432      0.785      0.433      -0.507       1.185
# weight_data (x)                      -0.4761      0.471     -1.010      0.313      -1.400       0.448
# education (x)                        -0.3587      0.193     -1.858      0.063      -0.737       0.020
# living___1 (x)                       -0.5022      0.660     -0.760      0.447      -1.797       0.792
# osteoporosis_judge_o 是否骨質疏鬆          -0.0307      0.715     -0.043      0.966      -1.433       1.371
# vivifrail_judge3 (x) SPPB分數是否大於9分    -0.1177      0.691     -0.170      0.865      -1.472       1.237
# mna_score (x)                        -2.8230      1.501     -1.880      0.060      -5.765       0.119
# menopause 早發性停經< 45歲 (x)            -20.1062   1.18e+04     -0.002      0.999   -2.32e+04    2.32e+04
# baseline_monthly 每個月收入多少             -0.6385      0.610     -1.046      0.295      -1.835       0.558
# frax_5(骨折史)                          -0.5438      0.901     -0.603      0.546      -2.311       1.223
# frax_7(目前吸菸)                          1.4633      1.607      0.910      0.363      -1.687       4.614
# frax_11 是否過度飲酒                      -28.0736    1.6e+06  -1.76e-05      1.000   -3.13e+06    3.13e+06
# frax_6 父母骨折史                          0.1265      1.538      0.082      0.934      -2.888       3.141
# frax_10 次發性骨鬆                        -0.0814      0.787     -0.103      0.918      -1.625       1.462
# frax_9 類風溼性關節炎                      -24.2936   1.55e+05     -0.000      1.000   -3.04e+05    3.04e+05
# dm 是否有糖尿病                             1.5615      0.599      2.607      0.009       0.387       2.736
# exercise                             -1.8102      0.602     -3.006      0.003      -2.991      -0.630
# (每年更新)follow_2 是否有跌倒                  3.5482      0.712      4.986      0.000       2.153       4.943
# sarcopenia_diagnosis 是否確診肌少症(X)       3.0428      1.361      2.236      0.025       0.375       5.710
# calf_judge 小腿圍是否不足(X)                -2.1545      0.722     -2.983      0.003      -3.570      -0.739
# hand_strength_judge 手握力是否不足(X)       -2.5957      1.236     -2.100      0.036      -5.018      -0.173
# sit_and_stand_up_judge 起立坐下          -0.4348      0.589     -0.739      0.460      -1.588       0.719
# sixm_sec_judge 6公尺步行速度太慢 (超過6秒)      -1.1985      0.811     -1.477      0.140      -2.789       0.392
# sarcopenia_judge 是否有肌肉質量不足(x)         0.0448      0.727      0.062      0.951      -1.381       1.470
# 兩者髖關節是否不正常合(X)                        1.6696      1.628      1.025      0.305      -1.521       4.861
# 兩者骨頸是否不正常(X)                        -18.0271   2.15e+04     -0.001      0.999   -4.21e+04    4.21e+04
# dxa_spinet_n 腰椎T值是否不正常               -1.4892      1.107     -1.345      0.179      -3.659       0.681
# =====================================================================================================
#
# Possibly complete quasi-separation: A fraction 0.13 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#
# P-values of Logit model:
# gender (x)                           4.747590e-01
# age (x)                              2.929975e-01
# height (x)                           4.326024e-01
# weight_data (x)                      3.125134e-01
# education (x)                        6.321447e-02
# living___1 (x)                       4.469833e-01
# osteoporosis_judge_o 是否骨質疏鬆          9.658203e-01
# vivifrail_judge3 (x) SPPB分數是否大於9分    8.647227e-01
# mna_score (x)                        6.004980e-02
# menopause 早發性停經< 45歲 (x)             9.986432e-01
# baseline_monthly 每個月收入多少             2.954922e-01
# frax_5(骨折史)                          5.463153e-01
# frax_7(目前吸菸)                         3.626504e-01
# frax_11 是否過度飲酒                       9.999860e-01
# frax_6 父母骨折史                         9.344273e-01
# frax_10 次發性骨鬆                        9.176231e-01
# frax_9 類風溼性關節炎                       9.998752e-01
# dm 是否有糖尿病                            9.140709e-03
# exercise                             2.649110e-03
# (每年更新)follow_2 是否有跌倒                 6.178940e-07
# sarcopenia_diagnosis 是否確診肌少症(X)      2.538261e-02
# calf_judge 小腿圍是否不足(X)                2.853541e-03
# hand_strength_judge 手握力是否不足(X)       3.572210e-02
# sit_and_stand_up_judge 起立坐下          4.600490e-01
# sixm_sec_judge 6公尺步行速度太慢 (超過6秒)      1.395837e-01
# sarcopenia_judge 是否有肌肉質量不足(x)        9.508327e-01
# 兩者髖關節是否不正常合(X)                       3.051385e-01
# 兩者骨頸是否不正常(X)                         9.993299e-01
# dxa_spinet_n 腰椎T值是否不正常               1.785988e-01
# dtype: float64
#
# Odds Ratios Logit model:
# gender (x)                           2.259719e+00
# age (x)                              1.469166e+00
# height (x)                           1.403181e+00
# weight_data (x)                      6.212312e-01
# education (x)                        6.985742e-01
# living___1 (x)                       6.051909e-01
# osteoporosis_judge_o 是否骨質疏鬆          9.698148e-01
# vivifrail_judge3 (x) SPPB分數是否大於9分    8.889309e-01
# mna_score (x)                        5.942520e-02
# menopause 早發性停經< 45歲 (x)             1.853504e-09
# baseline_monthly 每個月收入多少             5.280622e-01
# frax_5(骨折史)                          5.805320e-01
# frax_7(目前吸菸)                         4.320062e+00
# frax_11 是否過度飲酒                       6.423629e-13
# frax_6 父母骨折史                         1.134882e+00
# frax_10 次發性骨鬆                        9.217902e-01
# frax_9 類風溼性關節炎                       2.814591e-11
# dm 是否有糖尿病                            4.766039e+00
# exercise                             1.636252e-01
# (每年更新)follow_2 是否有跌倒                 3.475010e+01
# sarcopenia_diagnosis 是否確診肌少症(X)      2.096345e+01
# calf_judge 小腿圍是否不足(X)                1.159611e-01
# hand_strength_judge 手握力是否不足(X)       7.459612e-02
# sit_and_stand_up_judge 起立坐下          6.473933e-01
# sixm_sec_judge 6公尺步行速度太慢 (超過6秒)      3.016437e-01
# sarcopenia_judge 是否有肌肉質量不足(x)        1.045866e+00
# 兩者髖關節是否不正常合(X)                       5.309946e+00
# 兩者骨頸是否不正常(X)                         1.482233e-08
# dxa_spinet_n 腰椎T值是否不正常               2.255585e-01
# dtype: float64

# %%
# Decision Tree model
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train_Standardized, y_train)

# Access feature importance scores for decision tree
dt_feature_importance = dt_model.feature_importances_

print("Logistic Regression Feature Importance:")
for column, importance in zip(X_train_Standardized.columns,logit_result.params):
    print(f"{column} : {importance}")

print("\nDecision Tree Feature Importance:")
for column, importance in zip(X_train_Standardized.columns,dt_feature_importance):
    print(f"{column} : {importance}")
# Out:
# Logistic Regression Feature Importance:
# gender (x) : 0.8152403892724727
# age (x) : 0.38469493737322746
# height (x) : 0.33874191075905824
# weight_data (x) : -0.4760518937903041
# education (x) : -0.35871394845677523
# living___1 (x) : -0.5022113385434399
# osteoporosis_judge_o 是否骨質疏鬆 : -0.030650112989394372
# vivifrail_judge3 (x) SPPB分數是否大於9分 : -0.117735743648495
# mna_score (x) : -2.823036869263516
# menopause 早發性停經< 45歲 (x) : -20.106187716175654
# baseline_monthly 每個月收入多少 : -0.638541212300067
# frax_5(骨折史) : -0.5438103980439027
# frax_7(目前吸菸) : 1.4632697051764363
# frax_11 是否過度飲酒 : -28.07362304573344
# frax_6 父母骨折史 : 0.12652897850127284
# frax_10 次發性骨鬆 : -0.08143767285284068
# frax_9 類風溼性關節炎 : -24.293619099010172
# dm 是否有糖尿病 : 1.5615156424703343
# exercise : -1.8101768670230722
# (每年更新)follow_2 是否有跌倒 : 3.548182591657818
# sarcopenia_diagnosis 是否確診肌少症(X) : 3.042780608364132
# calf_judge 小腿圍是否不足(X) : -2.1545005953878245
# hand_strength_judge 手握力是否不足(X) : -2.595666783812338
# sit_and_stand_up_judge 起立坐下 : -0.4348012702828051
# sixm_sec_judge 6公尺步行速度太慢 (超過6秒) : -1.1985085948142113
# sarcopenia_judge 是否有肌肉質量不足(x) : 0.04484499107681862
# 兩者髖關節是否不正常合(X) : 1.6695817316401917
# 兩者骨頸是否不正常(X) : -18.027130989525272
# dxa_spinet_n 腰椎T值是否不正常 : -1.4891758644036444
#
# Decision Tree Feature Importance:
# gender (x) : 0.0
# age (x) : 0.11074444476467703
# height (x) : 0.04449869033658702
# weight_data (x) : 0.04015093772354223
# education (x) : 0.026617857699871475
# living___1 (x) : 0.0
# osteoporosis_judge_o 是否骨質疏鬆 : 0.0
# vivifrail_judge3 (x) SPPB分數是否大於9分 : 0.03667103784188834
# mna_score (x) : 0.0
# menopause 早發性停經< 45歲 (x) : 0.0
# baseline_monthly 每個月收入多少 : 0.021730985387785683
# frax_5(骨折史) : 0.012014022590180404
# frax_7(目前吸菸) : 0.0
# frax_11 是否過度飲酒 : 0.0
# frax_6 父母骨折史 : 0.05186858758859973
# frax_10 次發性骨鬆 : 0.021730985387785683
# frax_9 類風溼性關節炎 : 0.0
# dm 是否有糖尿病 : 0.18277734255253905
# exercise : 0.005095399111639148
# (每年更新)follow_2 是否有跌倒 : 0.32422207491521843
# sarcopenia_diagnosis 是否確診肌少症(X) : 0.0071879503426728625
# calf_judge 小腿圍是否不足(X) : 0.0
# hand_strength_judge 手握力是否不足(X) : 0.04244333083551892
# sit_and_stand_up_judge 起立坐下 : 0.04346197077557137
# sixm_sec_judge 6公尺步行速度太慢 (超過6秒) : 0.0
# sarcopenia_judge 是否有肌肉質量不足(x) : 0.0
# 兩者髖關節是否不正常合(X) : 0.012486143105083263
# 兩者骨頸是否不正常(X) : 0.0
# dxa_spinet_n 腰椎T值是否不正常 : 0.016298239040839265

# %%
def FS_RFECV(X_train,y_train,model,cv=5, step =1):
    # Create RFECV object with defeault step = 1 , cv = 5
    rfecv = RFECV(estimator = model, step=step, cv=cv)
    
    # Fit RFECV to training data
    rfecv.fit(X_train, y_train)

    # Get the selected features and names
    selected_features_names = X_train.columns[rfecv.support_].tolist()
    
    # Return the selected features and the optimal number of features
    print(f'\nThere are {rfecv.n_features_} selected features, including {selected_features_names}, for {type(model).__name__} model')
    # Store those feature into a new variable
    return selected_features_names

# %%
# Specify the models for feature selection
models = [LogisticRegression(),DecisionTreeClassifier()]

# Filter X_train and X_test with the selected feature names and store into a new variable
for model in models:
    # Store X_train and X_test with selected feature names into new variables
    selected_featurenames = FS_RFECV(X_train_Standardized, y_train,model)
    globals()[f'X_train_{type(model).__name__}'] = X_train[selected_featurenames]
    globals()[f'X_test_{type(model).__name__}'] = X_test[selected_featurenames]
# Out:
# There are 10 selected features, including ['mna_score (x)', 'menopause 早發性停經< 45歲 (x)', 'frax_9 類風溼性關節炎', 'dm 是否有糖尿病', 'exercise', '(每年更新)follow_2 是否有跌倒', 'sarcopenia_diagnosis 是否確診肌少症(X)', 'calf_judge 小腿圍是否不足(X)', 'hand_strength_judge 手握力是否不足(X)', 'sixm_sec_judge 6公尺步行速度太慢 (超過6秒)'], for LogisticRegression model
#
# There are 21 selected features, including ['age (x)', 'height (x)', 'weight_data (x)', 'education (x)', 'living___1 (x)', 'osteoporosis_judge_o 是否骨質疏鬆', 'vivifrail_judge3 (x) SPPB分數是否大於9分', 'mna_score (x)', 'menopause 早發性停經< 45歲 (x)', 'baseline_monthly 每個月收入多少', 'frax_5(骨折史)', 'frax_6 父母骨折史', 'frax_10 次發性骨鬆', 'frax_9 類風溼性關節炎', 'dm 是否有糖尿病', 'exercise', '(每年更新)follow_2 是否有跌倒', 'sarcopenia_diagnosis 是否確診肌少症(X)', 'calf_judge 小腿圍是否不足(X)', 'hand_strength_judge 手握力是否不足(X)', 'sit_and_stand_up_judge 起立坐下'], for DecisionTreeClassifier model

# %% [markdown]
# # Part 5-3 : 模型參數微調 & 原始資料檢驗

# %% [markdown]
# 本次以Logistic Regression、Decision Tree、ANN三個模型進行優化，先透過交叉驗證做出最好的模型參數

# %%
# Input for CV
models = [LogisticRegression(),DecisionTreeClassifier(),MLPClassifier()]

# (ANN use selected feature of DecisionTreeClassifier)
X_trains_Selected = [X_train_LogisticRegression,X_train_DecisionTreeClassifier,X_train_DecisionTreeClassifier]
X_tests_Selected = [X_test_LogisticRegression,X_test_DecisionTreeClassifier,X_test_DecisionTreeClassifier]

param_grids = [
    {'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'saga']},
    {'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10, 15, 20],
    'min_samples_split': [2, 5, 10]},
    {'hidden_layer_sizes': [(50,), (100,), (50, 50), (100, 100)],
    'activation': ['relu', 'tanh'],
    'alpha': [0.0001, 0.001, 0.01]}]

# %% [markdown]
# 以下選用accuracy做標準做交叉驗證

# %%
def CV(X_train, X_test, y_train, y_test,model, param_grid,scoring,n_splits = 5,shuffle = True):
    # Cross-validate with stratified sampling, shuffle before sampling
    cv = StratifiedKFold(n_splits=n_splits, shuffle = shuffle, random_state=42)
    
    # Perform grid search with different cv value, use accura
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=cv, scoring=scoring, return_train_score=True)
    grid_search.fit(X_train, y_train)

    # Get the best parameters and corresponding score
    best_params = grid_search.best_params_
    best_train_score = grid_search.best_score_
    # Make predictions on the test set using the best model
    best_model = grid_search.best_estimator_
    # Calculate the score on the test set using the best model
    best_test_score = best_model.score(X_test, y_test)
    # Calculate the score difference of train score and test score
    best_score_diff = abs(best_train_score - best_test_score)
    
    # Print the best model and its score
    print(f"The attribute of the best model (greatest test Score) of {type(model).__name__}:")
    print(f"Model : {best_model}")
    print(f"Train Score : {best_train_score}")
    print(f"Test Score : {best_test_score}")
    print(f"Score Difference : {best_score_diff}")
    print()

    return best_model

# %%
def ConfusionMatrix(X_train, X_test, y_train, y_test,best_model):
    # fit the train set with the best model
    best_model.fit(X_train, y_train)
    y_pred = best_model.predict(X_test)
    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    
    # Plot confusion matrix
    plt.figure(figsize=(6, 4))
    confusion_matrix = metrics.ConfusionMatrixDisplay(confusion_matrix = cm,display_labels = ['Negative', 'Positive'])
    confusion_matrix.plot(cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()
    
    # Generate classification report
    report = classification_report(y_test, y_pred, target_names=['Class 0', 'Class 1'])
    
    # Print classification report
    print("Classification Report:")
    print(report)

# %% [markdown]
# 這邊處理原始資料直接跑三個被optimized的model,看confusion matrix與被oversample後data的差異

# %%
# Split the original data into train and test sets with stratification sampling
X_train_Original, X_test_Original, y_train_Original, y_test_Original = train_test_split(X, y, test_size=0.3, stratify=y, random_state = 20)

# Standardize the features (mean=0 and variance=1)
Columns = ['age (x)','height (x)','weight_data (x)']
scaler = StandardScaler()

# Get a copy of the original X_train and X_test
X_train_Original_Standardized = X_train_Original.copy() 
X_test_Original_Standardized = X_test_Original.copy()

# Fit and transform X_train and then transform X_test 
X_train_Original_Standardized[Columns] = scaler.fit_transform(X_train_Original_Standardized[Columns])
X_test_Original_Standardized[Columns] = scaler.transform(X_test_Original_Standardized[Columns])

# Filter X_train and X_test with the features selected for Decision Tree model
X_train_Original_Selected = X_train_Original_Standardized[X_train_DecisionTreeClassifier.columns.tolist()]
X_test_Original_Selected = X_test_Original_Standardized[X_test_DecisionTreeClassifier.columns.tolist()]

# %%
# Put the combination of model and param_grid into function
for model, param_grid,X_train_Selected,X_test_Selected in zip(models,param_grids,X_trains_Selected,X_tests_Selected):
    best_model = CV(X_train_Selected,X_test_Selected, y_train, y_test, model, param_grid, 'accuracy')
    print(f'\nConfusion matrix of best {type(best_model).__name__} with resampled data :')
    ConfusionMatrix(X_train_Selected,X_test_Selected, y_train, y_test, best_model)
    print(f'\nConfusion matrix of best {type(best_model).__name__} with original data :')
    ConfusionMatrix(X_train_Original_Selected, X_test_Original_Selected, y_train_Original, y_test_Original, best_model)
# Out:
# The attribute of the best model (greatest test Score) of LogisticRegression:
# Model : LogisticRegression(C=100, penalty='l1', solver='saga')
# Train Score : 0.9195859213250518
# Test Score : 0.9133333333333333
# Score Difference : 0.006252587991718461
#
#
# Confusion matrix of LogisticRegression with resampled data :
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.95      0.96      0.95       135
#      Class 1       0.57      0.53      0.55        15
#
#     accuracy                           0.91       150
#    macro avg       0.76      0.74      0.75       150
# weighted avg       0.91      0.91      0.91       150
#
#
# Confusion matrix of LogisticRegression with original data :
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.96      0.99      0.97       135
#      Class 1       0.00      0.00      0.00         6
#
#     accuracy                           0.95       141
#    macro avg       0.48      0.50      0.49       141
# weighted avg       0.92      0.95      0.93       141
#
# The attribute of the best model (greatest test Score) of DecisionTreeClassifier:
# Model : DecisionTreeClassifier(max_depth=10, min_samples_split=5)
# Train Score : 0.911055900621118
# Test Score : 0.8666666666666667
# Score Difference : 0.04438923395445127
#
#
# Confusion matrix of DecisionTreeClassifier with resampled data :
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.95      0.91      0.93       135
#      Class 1       0.40      0.53      0.46        15
#
#     accuracy                           0.87       150
#    macro avg       0.67      0.72      0.69       150
# weighted avg       0.89      0.87      0.88       150
#
#
# Confusion matrix of DecisionTreeClassifier with original data :
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.96      0.95      0.96       135
#      Class 1       0.12      0.17      0.14         6
#
#     accuracy                           0.91       141
#    macro avg       0.54      0.56      0.55       141
# weighted avg       0.93      0.91      0.92       141
#
# The attribute of the best model (greatest test Score) of MLPClassifier:
# Model : MLPClassifier(activation='tanh', alpha=0.01, hidden_layer_sizes=(50, 50))
# Train Score : 0.9225258799171842
# Test Score : 0.9
# Score Difference : 0.022525879917184133
#
#
# Confusion matrix of MLPClassifier with resampled data :
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.94      0.96      0.95       135
#      Class 1       0.55      0.40      0.46        15
#
#     accuracy                           0.91       150
#    macro avg       0.74      0.68      0.71       150
# weighted avg       0.90      0.91      0.90       150
#
#
# Confusion matrix of MLPClassifier with original data :
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.96      0.99      0.97       135
#      Class 1       0.00      0.00      0.00         6
#
#     accuracy                           0.95       141
#    macro avg       0.48      0.50      0.49       141
# weighted avg       0.92      0.95      0.93       141

# %% [markdown]
# 可以看出在原始資料中，原本該是1的樣本大都被預測錯誤，而原本是0的樣本大都被預測正確，推測與原始樣本的1過少有關。
